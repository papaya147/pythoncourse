# %%
from sklearn.datasets import make_blobs

data, true_labels = make_blobs(n_samples = 500,centers = 4,random_state = 6)

# %%
from pandas import DataFrame

points = DataFrame(data, columns = ["x1", "x2"])
points.plot.scatter("x1","x2")
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 4).fit(points)

# %%
cluster_centers = DataFrame(kmeans.cluster_centers_,columns = ["x1", "x2"])
cluster_centers
# Out:
#          x1        x2
# 0  6.485156 -9.212537
# 1 -7.857994  1.892259
# 2  0.485425 -1.628580
# 3  7.886559 -3.337117

# %%
ax = points.plot.scatter("x1","x2")
cluster_centers.plot.scatter("x1","x2",ax = ax,c = "red",s = 200,marker = "x")
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
kmeans.labels_ # this is the cluster to which the data belongs
# Out:
# array([2, 0, 3, 2, 1, 1, 0, 1, 0, 2, 1, 3, 2, 3, 3, 3, 3, 1, 3, 3, 1, 0,
#        2, 3, 0, 2, 0, 3, 1, 0, 3, 1, 1, 0, 0, 1, 1, 2, 3, 3, 3, 1, 3, 1,
#        1, 3, 3, 3, 0, 0, 2, 1, 2, 0, 0, 1, 0, 1, 1, 1, 1, 2, 2, 0, 0, 0,
#        3, 0, 0, 0, 1, 2, 3, 1, 0, 1, 3, 3, 3, 3, 0, 1, 0, 3, 3, 3, 1, 0,
#        2, 2, 3, 0, 1, 3, 1, 3, 1, 3, 2, 0, 0, 2, 3, 3, 3, 1, 3, 0, 3, 0,
#        0, 0, 3, 2, 2, 2, 3, 3, 0, 2, 2, 1, 3, 3, 3, 1, 2, 0, 3, 0, 0, 3,
#        1, 3, 1, 2, 0, 1, 0, 3, 0, 3, 1, 0, 3, 3, 0, 3, 2, 1, 1, 0, 2, 3,
#        1, 0, 0, 1, 0, 0, 1, 3, 2, 3, 1, 0, 1, 2, 3, 2, 1, 1, 2, 0, 2, 1,
#        3, 0, 1, 1, 2, 0, 0, 0, 0, 3, 0, 3, 1, 0, 1, 2, 1, 2, 1, 1, 0, 1,
#        0, 3, 2, 1, 1, 2, 0, 3, 3, 3, 1, 1, 2, 2, 2, 1, 3, 2, 1, 0, 3, 3,
#        1, 2, 2, 2, 3, 1, 1, 2, 0, 0, 0, 2, 2, 2, 2, 0, 1, 0, 3, 2, 2, 2,
#        0, 1, 1, 0, 3, 1, 2, 3, 0, 1, 2, 3, 1, 2, 3, 1, 1, 0, 2, 2, 2, 1,
#        3, 1, 1, 3, 0, 3, 2, 2, 0, 2, 2, 3, 1, 1, 2, 1, 2, 1, 2, 3, 0, 2,
#        1, 3, 2, 2, 0, 3, 3, 0, 2, 1, 1, 3, 2, 3, 3, 2, 2, 3, 2, 2, 2, 0,
#        3, 3, 1, 0, 1, 2, 1, 3, 3, 2, 3, 3, 3, 0, 1, 2, 1, 0, 3, 3, 2, 1,
#        2, 0, 2, 3, 2, 2, 1, 0, 3, 2, 0, 0, 2, 3, 0, 2, 1, 2, 2, 0, 3, 2,
#        3, 2, 0, 0, 2, 2, 0, 1, 1, 0, 3, 3, 3, 3, 2, 1, 2, 1, 2, 1, 2, 2,
#        2, 2, 2, 1, 2, 0, 3, 0, 1, 1, 0, 0, 2, 1, 3, 3, 3, 0, 3, 1, 3, 1,
#        0, 0, 1, 0, 0, 2, 0, 0, 0, 0, 3, 1, 2, 2, 1, 0, 0, 0, 1, 1, 1, 1,
#        2, 0, 2, 1, 0, 3, 2, 3, 1, 0, 0, 3, 1, 0, 3, 1, 1, 2, 2, 1, 3, 0,
#        3, 2, 3, 1, 3, 0, 3, 0, 2, 2, 2, 3, 0, 3, 1, 3, 2, 1, 0, 0, 2, 1,
#        2, 2, 1, 0, 2, 2, 0, 1, 2, 1, 0, 0, 0, 3, 0, 0, 0, 2, 0, 2, 3, 1,
#        1, 3, 1, 3, 2, 3, 0, 2, 2, 0, 1, 1, 2, 1, 0, 3])

# %%
points.plot.scatter("x1", "x2", c = kmeans.labels_, colormap = "Accent", colorbar = False)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# # Exercise

# %%
from sklearn.datasets import load_iris
iris = DataFrame(load_iris().data, columns = load_iris().feature_names)
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
num_iris_species = len(load_iris().target_names)
num_iris_species
# Out:
# 3

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = num_iris_species).fit(iris)

# %%
from pandas.plotting import scatter_matrix

a = scatter_matrix(iris, figsize = (16, 16), c = kmeans.labels_)

# %% [markdown]
# # Inertia

# %% [markdown]
# Generally low inertia = good solution

# %%
from pandas import Series, DataFrame
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

data, true_labels = make_blobs(n_samples = 500, centers = 4, random_state = 6)
point = DataFrame(data, columns = ["x1", "x2"])

inertia_values = []
r = pd.RangeIndex(2,8)
for n_clusters in r:
    kmeans = KMeans(n_clusters = n_clusters).fit(points)
    inertia_values.append(kmeans.inertia_)
    
inertia = Series(inertia_values, name = "inertia", index = r)
inertia.plot()
# Out:
# <AxesSubplot:>
